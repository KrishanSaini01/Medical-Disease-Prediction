# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("Data\\medical_disease.csv")

# %%
df
# Out:
#       Age  Gender   BMI  BloodPressure  GlucoseLevel  Cholesterol  HeartRate  \
# 0      23    Male  17.5            102           177          161         88
# 1      69    Male  31.1            118           256          147         92
# 2      61  Female  31.3            114           206          193         74
# 3      47  Female  23.9            105           162          253         68
# 4      47    Male  28.3            148           121          280         84
# ...   ...     ...   ...            ...           ...          ...        ...
# 9995   49    Male  27.1            177           183          268         59
# 9996   84    Male  29.2            142           215          145         77
# 9997   41    Male  22.8            177           265          133         71
# 9998   55    Male  29.0            126           241          298         57
# 9999   59    Male  32.2            151           162          225         93
#
# ...

# %%
print("Shape of Dataset:", df.shape)
# Out:
# Shape of Dataset: (10000, 12)

# %%
print(df.columns)
# Out:
# Index(['Age', 'Gender', 'BMI', 'BloodPressure', 'GlucoseLevel', 'Cholesterol',
#        'HeartRate', 'Smoking', 'Alcohol', 'PhysicalActivity', 'FamilyHistory',
#        'Disease'],
#       dtype='object')

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               10000 non-null  int64
#  1   Gender            10000 non-null  object
#  2   BMI               10000 non-null  float64
#  3   BloodPressure     10000 non-null  int64
#  4   GlucoseLevel      10000 non-null  int64
#  5   Cholesterol       10000 non-null  int64
#  6   HeartRate         10000 non-null  int64
#  7   Smoking           10000 non-null  object
#  8   Alcohol           10000 non-null  object
#  9   PhysicalActivity  10000 non-null  object
#  10  FamilyHistory     10000 non-null  object
#  11  Disease           10000 non-null  object
# dtypes: float64(1), int64(5), object(6)
# memory usage: 937.6+ KB
# None

# %%
print(df.isnull().sum())
# Out:
# Age                 0
# Gender              0
# BMI                 0
# BloodPressure       0
# GlucoseLevel        0
# Cholesterol         0
# HeartRate           0
# Smoking             0
# Alcohol             0
# PhysicalActivity    0
# FamilyHistory       0
# Disease             0
# dtype: int64

# %%
print( df.duplicated().sum())
# Out:
# 0

# %%
df = df.drop_duplicates()

# %%
print( df.duplicated().sum())
# Out:
# 0

# %%
for col in df.columns:
    print("\nColumn:", col)
    print(df[col].unique())
# Out:
# Column: Age
# [23 69 61 47 75 64 31 24 53 83 67 68 66 70 52 26 74 48 51 42 30 80 44 73
#  54 33 55 77 22 36 60 29 41 63 49 20 28 79 82 45 39 78 71 40 62 81 38 43
#  37 34 27 18 65 56 25 58 32 84 21 46 72 19 35 57 59 50 76]
#
# Column: Gender
# ['Male' 'Female']
#
# Column: BMI
# [17.5 31.1 31.3 23.9 28.3 25.  27.1 20.8 28.8 18.6 17.8 25.5 27.2 23.1
#  34.5 26.7 27.  26.9 30.5 28.6 28.  29.3 18.  25.7 25.1 26.1 20.4 26.
#  20.  27.7 27.6 19.4 24.3 30.  23.  19.2 18.4 26.5 28.5 28.7 25.9 24.8
#  21.2 24.  20.1 22.2 26.4 39.8 19.9 25.4 19.6 24.4 29.8 24.1 19.7 26.3
#  24.9 18.3 28.4 22.9 29.4 31.9 25.2 21.4 24.6 23.5 28.2 28.1 22.5 28.9
#  17.1 31.7 27.8 20.6 29.1 23.8 29.7 17.9 21.3 16.7 22.  32.8 35.3 19.
#  23.4 32.5 22.6 27.3 23.2 34.8 25.8 32.9 30.8 25.6 19.5 31.5 27.9 21.6
#  23.7 34.3 35.  21.8 29.9 31.8 26.6 19.1 26.8 29.5 22.4 16.4 25.3 30.7
#  29.6 30.6 16.  33.8 37.1 18.1 24.5 30.9 20.2 30.3 30.1 27.4 32.2 17.7
# ...

# %%
Gender_list = df['Gender'].unique().tolist()
Gender_dict = {Gender: i for i, Gender in enumerate(Gender_list)}
print(Gender_dict)
df['Gender'] = df['Gender'].map(Gender_dict)


df['Smoking'] = df['Smoking'].map({'No':0,'Yes':1}).astype(int)

df['Alcohol'] = df['Alcohol'].map({ 'No':0,'Yes':1})

df['FamilyHistory'] = df['FamilyHistory'].map({'No':0,'Yes':1})

df['PhysicalActivity'] = df['PhysicalActivity'].map({'Medium':2, 'High':3, 'Low':1})

df['Disease'] = df['Disease'].map({'Healthy':1, 'Pre-Diabetes':2, 'Hypertension':3, 'Heart Disease':4, 'Diabetes':5})
# Out:
# {'Male': 0, 'Female': 1}

# %%
df
# Out:
#       Age  Gender   BMI  BloodPressure  GlucoseLevel  Cholesterol  HeartRate  \
# 0      23       0  17.5            102           177          161         88
# 1      69       0  31.1            118           256          147         92
# 2      61       1  31.3            114           206          193         74
# 3      47       1  23.9            105           162          253         68
# 4      47       0  28.3            148           121          280         84
# ...   ...     ...   ...            ...           ...          ...        ...
# 9995   49       0  27.1            177           183          268         59
# 9996   84       0  29.2            142           215          145         77
# 9997   41       0  22.8            177           265          133         71
# 9998   55       0  29.0            126           241          298         57
# 9999   59       0  32.2            151           162          225         93
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               10000 non-null  int64
#  1   Gender            10000 non-null  int64
#  2   BMI               10000 non-null  float64
#  3   BloodPressure     10000 non-null  int64
#  4   GlucoseLevel      10000 non-null  int64
#  5   Cholesterol       10000 non-null  int64
#  6   HeartRate         10000 non-null  int64
#  7   Smoking           10000 non-null  int64
#  8   Alcohol           10000 non-null  int64
#  9   PhysicalActivity  10000 non-null  int64
#  10  FamilyHistory     10000 non-null  int64
#  11  Disease           10000 non-null  int64
# dtypes: float64(1), int64(11)
# memory usage: 937.6 KB

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# Age                 0
# Gender              0
# BMI                 0
# BloodPressure       0
# GlucoseLevel        0
# Cholesterol         0
# HeartRate           0
# Smoking             0
# Alcohol             0
# PhysicalActivity    0
# FamilyHistory       0
# Disease             0
# dtype: int64

# %%
df.to_csv("medical_disease_cleaned.csv",index=False)

# %%
x = df.drop('Disease', axis=1)
y = df['Disease']

# %%
x
# Out:
#       Age  Gender   BMI  BloodPressure  GlucoseLevel  Cholesterol  HeartRate  \
# 0      23       0  17.5            102           177          161         88
# 1      69       0  31.1            118           256          147         92
# 2      61       1  31.3            114           206          193         74
# 3      47       1  23.9            105           162          253         68
# 4      47       0  28.3            148           121          280         84
# ...   ...     ...   ...            ...           ...          ...        ...
# 9995   49       0  27.1            177           183          268         59
# 9996   84       0  29.2            142           215          145         77
# 9997   41       0  22.8            177           265          133         71
# 9998   55       0  29.0            126           241          298         57
# 9999   59       0  32.2            151           162          225         93
#
# ...

# %%
y
# Out:
# 0       1
# 1       2
# 2       1
# 3       1
# 4       1
#        ..
# 9995    3
# 9996    3
# 9997    3
# 9998    2
# 9999    2
# Name: Disease, Length: 10000, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,train_size=0.8,random_state=42)

# %%
x_train
# Out:
#       Age  Gender   BMI  BloodPressure  GlucoseLevel  Cholesterol  HeartRate  \
# 9254   76       0  29.6            134           266          318        101
# 1561   35       1  29.3             96           220          300         58
# 1670   69       0  29.6            164           149          229         98
# 6087   47       0  29.0            159           250          258        109
# 6669   42       0  23.4            107           224          300         82
# ...   ...     ...   ...            ...           ...          ...        ...
# 5734   61       1  30.2            175           147          167        102
# 5191   79       1  20.5            150           225          142         84
# 5390   30       0  27.6            119           101          129        110
# 860    82       0  30.7            108           143          231        102
# 7270   38       0  17.3            176            89          284         66
#
# ...

# %%
x_test
# Out:
#       Age  Gender   BMI  BloodPressure  GlucoseLevel  Cholesterol  HeartRate  \
# 6252   36       0  23.5            122           156          146         99
# 4684   52       1  23.0            147           137          273        107
# 1731   78       0  26.3            118           128          125         55
# 4742   46       0  22.6            161           211          147         59
# 4521   64       1  27.2            126           261          162        108
# ...   ...     ...   ...            ...           ...          ...        ...
# 6412   23       1  25.5            114           204          220         99
# 8285   20       0  32.3            131           257          287         77
# 7853   53       1  26.8            180           240          306         94
# 1095   23       1  35.2            118           148          292        100
# 6929   68       1  16.5            105           117          307         62
#
# ...

# %%
y_train
# Out:
# 9254    3
# 1561    1
# 1670    1
# 6087    1
# 6669    1
#        ..
# 5734    2
# 5191    1
# 5390    1
# 860     3
# 7270    3
# Name: Disease, Length: 8000, dtype: int64

# %%
y_test
# Out:
# 6252    1
# 4684    1
# 1731    1
# 4742    1
# 4521    3
#        ..
# 6412    1
# 8285    1
# 7853    3
# 1095    1
# 6929    1
# Name: Disease, Length: 2000, dtype: int64

# %%
print(x_train.shape,x_test.shape,y_train.shape,y_test.shape)
# Out:
# (8000, 11) (2000, 11) (8000,) (2000,)

# %%
df
# Out:
#       Age  Gender   BMI  BloodPressure  GlucoseLevel  Cholesterol  HeartRate  \
# 0      23       0  17.5            102           177          161         88
# 1      69       0  31.1            118           256          147         92
# 2      61       1  31.3            114           206          193         74
# 3      47       1  23.9            105           162          253         68
# 4      47       0  28.3            148           121          280         84
# ...   ...     ...   ...            ...           ...          ...        ...
# 9995   49       0  27.1            177           183          268         59
# 9996   84       0  29.2            142           215          145         77
# 9997   41       0  22.8            177           265          133         71
# 9998   55       0  29.0            126           241          298         57
# 9999   59       0  32.2            151           162          225         93
#
# ...

# %% [markdown]
# # SVM (SVR)

# %%
from sklearn.svm import SVR
sv=SVR()
sv.fit(x_train,y_train)
# Out:
# SVR()

# %%
print('SVR test score:-',sv.score(x_test,y_test))
print('SVR train score:-',sv.score(x_train,y_train))
# Out:
# SVR test score:- 0.21312438447786386
# SVR train score:- 0.19048329546751752

# %% [markdown]
# # SVM (SVC)

# %%
from sklearn.svm import SVC
sv=SVC()
sv.fit(x_train,y_train)
# Out:
# SVC()

# %%
print('SVC test score:-',sv.score(x_test,y_test))
print('SVC train score:-',sv.score(x_train,y_train))
# Out:
# SVC test score:- 0.6395
# SVC train score:- 0.63125

# %% [markdown]
# # LinearRegression

# %%
from sklearn.linear_model import LinearRegression
lr= LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print('LinearRegression test score:-',lr.score(x_test,y_test))
print('LinearRegression train score:-',lr.score(x_train,y_train))
# Out:
# LinearRegression test score:- 0.41233703387196996
# LinearRegression train score:- 0.3825630863031215

# %% [markdown]
# # LogisticRegression

# %%
from sklearn.linear_model import LogisticRegression
log =LogisticRegression()
log.fit(x_train,y_train)
# Out:
# c:\Users\KRISHAN\Downloads\data science\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:599: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
print("LogisticRegression training",log.score(x_train,y_train))
print("LogisticRegression testing",log.score(x_test,y_test))
# Out:
# LogisticRegression training 0.631125
# LogisticRegression testing 0.642

# %% [markdown]
# # DecisionTreeClassifier

# %%
from sklearn.tree import DecisionTreeClassifier
dt =DecisionTreeClassifier()
dt.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
print('DecisionTreeClassifier test score:-',dt.score(x_test,y_test))
print('DecisionTreeClassifier train score:-',dt.score(x_train,y_train))
# Out:
# DecisionTreeClassifier test score:- 0.647
# DecisionTreeClassifier train score:- 1.0

# %% [markdown]
# # with parameters

# %%
from sklearn.tree import DecisionTreeClassifier
dt =DecisionTreeClassifier(criterion='entropy', min_samples_split=3, min_samples_leaf=2, random_state=42)
dt.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', min_samples_leaf=2,
#                        min_samples_split=3, random_state=42)

# %%
print('DecisionTreeClassifier test score:-',dt.score(x_test,y_test))
print('DecisionTreeClassifier train score:-',dt.score(x_train,y_train))
# Out:
# DecisionTreeClassifier test score:- 0.656
# DecisionTreeClassifier train score:- 0.94275

# %% [markdown]
# # DecisionTreeRegressor

# %%
from sklearn.tree import DecisionTreeRegressor
dt =DecisionTreeRegressor()
dt.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
print('DecisionTreeRegressor test score:-',dt.score(x_test,y_test))
print('DecisionTreeRegressor train score:-',dt.score(x_train,y_train))
# Out:
# DecisionTreeRegressor test score:- 0.25682578917935406
# DecisionTreeRegressor train score:- 1.0

# %% [markdown]
# # with parameters

# %%
from sklearn.tree import DecisionTreeRegressor
dt = DecisionTreeRegressor(criterion='squared_error',min_samples_split=3,min_samples_leaf=2,random_state=42)
dt.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor(min_samples_leaf=2, min_samples_split=3, random_state=42)

# %%
print("DecisionTreeRegressor Test Score:", dt.score(x_test, y_test))
print("DecisionTreeRegressor Train Score:", dt.score(x_train, y_train))
# Out:
# DecisionTreeRegressor Test Score: 0.33640469324281963
# DecisionTreeRegressor Train Score: 0.9558519566074887
